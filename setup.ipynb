# %%
# %sql
CREATE CATALOG IF NOT EXISTS ipl

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ipl.bronze;
CREATE SCHEMA IF NOT EXISTS ipl.raw;
CREATE SCHEMA IF NOT EXISTS ipl.silver;
CREATE SCHEMA IF NOT EXISTS ipl.gold;
