-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS `lh_ipl_eloc`
URL 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net'
WITH (STORAGE CREDENTIAL `lh-ipl-cred`)
COMMENT 'ADLS gen2 location'

-- %%
CREATE CATALOG IF NOT EXISTS ipl
MANAGED LOCATION 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net/ipl/lhConfigs';

CREATE SCHEMA IF NOT EXISTS ipl.bronze MANAGED LOCATION 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net/ipl/bronze';
CREATE SCHEMA IF NOT EXISTS ipl.silver MANAGED LOCATION 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net/ipl/silver';
CREATE SCHEMA IF NOT EXISTS ipl.gold MANAGED LOCATION 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net/ipl/gold';
CREATE SCHEMA IF NOT EXISTS ipl.config MANAGED LOCATION 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net/ipl/lhConfigs';

-- %%
CREATE TABLE IF NOT EXISTS ipl.config.lh_versions( Id INT NOT NULL
                                          , StartDate TIMESTAMP NOT NULL
                                          , EndDate TIMESTAMP
                                          , VersionNumber STRING
                                          , DeploymentNumber INT
                                          , CONSTRAINT PK_lh_versions PRIMARY KEY (Id)
) USING DELTA
LOCATION 'abfss://con-lh-ipl@adlstestlakehouse1.dfs.core.windows.net/ipl/lhConfigs/tables'
